# %% [markdown]
# 1. What is indentation error? Why indentation is important? Give one simple example?
#
#
# ##Ans:
# - identation error is error occur when we forget to give proper space, tab at the time when we define the function or any kind of block of code.
# -identation helps in readibility of the code, usually python interpretor does not know about excution sequence of the code. identation helps the code to execute line by line.
#
# ##following example gives me the error
#   ```python
# if 4>2:
# print(yes)
# else:
# print(no)
# ```
# ```python
# IndentationError: expected an indented block
# ```
# ##But the following give me right output:
#  ```python
# if 4>2:
#   print("yes")
# else:
#   print("no")
# ```
#
# ##output:-
# ```python
# yes
# ```
#
# 2. Correct the following code and write the comment where you made the correction?
# ##Ans:
# #corrected code
#   ```python
#   class_started = bool(int(input("Hey friend, is class started?: [0-False/1-True]")))
#
#   if class_started:
#       print("Since class started...")
#       print("Lets concentrate")
#   else:
#       print("Since class is not started...")
#       print("let's revise")
#   ```
#
#   **HINT:** Refer your data type conversion class
#
# 3. Use if else condition to verify that dataype of `input()` method in python is always string.
#
# ##Ans:
# Usually in input() function always gives you string datatype as output, there is no need for verification but still we have followind code
#
# ``` python
# a=input()
# if type(a)==str:
#   print(a)
# ```
#
# 4. Take 3 variables and assign integer values to them. Find the largest variable, by only using the if and else conditions.
#
# Ans:
# ```python
# a=8
# b=7
# c=10
# if a>b and a>c:
#   print("a is large")
# elif b>a and b>c:
#   print("b is large")
# else:
#   print("c is large")
#
# ```
#
#
# 5. What would be the solution?
#     1. True
#     2. False
#
#     ```python
#     a = 6
#     b = 10
#     print( not ( not a == 10 or not b == 10) )
#     ```
#
#   ##Ans: False
#
# 6. Find the answer as well as find out the reason behind the result? -
#     - case 1:
#         ```python
#         A = 5.0
#         B = 10/2
#         print(A is B)
#         ```
#     - case 2:
#         ```python
#         A = 5.0
#         B = int(10/2)
#         print(A is B)
#         ```
#     - case 3:
#         ```python
#         A = 5.0
#         B = float(10/2)
#         print(A is B)
#         ```
#
# ##Ans:
# All the above cases gives the output False, because "is" is identity operator and it compare the memory locations of the two object,here A and B are the two variable  assigned to different memory location.
# they will always gives False as output.

# %% [markdown]
# ### Try to understand the following examples and answer the question based on it -
#
# **Arithmatic Operators**
#
# |Operation|Meaning|
# |:-:|:-:|
# | **+** |addition|
# | **-** |subtraction|
# | **\*** |multiplication|
# | **/** |true division|
# | **//** |integer division|
# | **%** |the modulo operator|
#
#
# Here `+`, `-`, `*`, `/` are regular arithmatic operators. Lets look at the `//` and `%` operators
#
# Usecase or examples -
#
# ```python
# var_a = 5
# var_b = 25
# integer_division = var_b // var_a
# print(f"integer division: {var_b}/{var_a}={integer_division}")
# ```
#
# OUTPUT: integer division: 25/5=5
#
# ```python
# var_a = 3
# var_b = 25
# integer_division = var_b // var_a
# print(f"integer division: {var_b}/{var_a}={integer_division}")
# ```
#
# OUTPUT: integer division: 25/3=8
#
# ```python
# var_a = 5
# var_b = 25
# remainder = var_b % var_a
# print(f"remainder: {var_b}/{var_a} is {remainder}")
# ```
#
# OUTPUT: remainder: 25/5 is 0
#
# ```python
# var_a = 3
# var_b = 25
# remainder = var_b % var_a
# print(f"remainder: {var_b}/{var_a} is {remainder}")
# ```
#
# OUTPUT: remainder: 25/3 is 1

# %% [markdown]
# ### Answer below questions on the above theory -
#
# 7. Write a program that asks the user to enter a number. You should print out a message to the user, either “That number is divisible by either 3 or 5”, or “That number is not divisible by either 3 or 5”. Be sure to consider the data type of the input you are taking in from the user. Use a single if/else block to solve this problem.
#
#
# ##Ans:
#
# ```python
# A = int(input("Enter a number: "))
# if A % 5 == 0 or A % 3 == 0:
#   print(f"the number {A} divisible by either 3 or 5")
# else:
#   print(f"That number {A} is not divisible by either 3 or 5")
# ```
#
# 8. Take user input for length and width. Then calculate the area of rectangle. Also print as per length and width whether its a square of rectangle.
#
# ##Ans:
# ``` python
#
# leng = int(input("Enter the length: "))
# wid = int(input("Enter the width: "))
#
# Area = leng * wid
#
# if leng==wid:
#   print(f"its square and its Area is {Area}")
# else:
#   print(f"the area of rectangle is {Area}")
# ```
#
# 9. Take two variable radius_1 and radius_2 and calculate the area of circle_1 and circle_2. Also print which circle has large area. If area is equal then print area is equal.
#
# ##Ans:
# ```python
# rad_1 = int(input("Enter the radius of 1st circle: "))
# rad_2 = int(input("Enter the radius of 2nd circle: "))
#
# Area_1 = int(3.14 * rad_1 **2)
# Area_2 = int(3.14 * rad_2 **2)
# print(f"area of first circle is {Area_1}")
# print(f"area of second circle is {Area_2}")
# if Area_1 == Area_2:
#   print(f"The area of both circle is same.")
# elif Area_1 > Area_2:
#   print(f"the area of 1st circle is large")
# else:
#   print(f"the area of 2nd circle is large")
#
# ```
#
# 10. Check whether a year is leap year or not. Use nested if...else to solve this problem. A leap year is exactly divisible by 4 except for century years (years ending with 00). The century year is a leap year only if it is perfectly divisible by 400.
#
# ##Ans:
# ```python
# year = int(input("which year do you want to check: "))
#
# if year % 4 == 0:
#   if year % 100 == 0:
#     if year % 400 == 0:
#       print("Leap year")
#     else:
#       print("not leap year.")
#   else:
#     print("leap year")
# else:
#   print("Not leap year")
#
# ```
